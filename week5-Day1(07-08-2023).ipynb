# %% [markdown]
# #### Data Cleaning:
# - 1. isnull():
#             - To check the data having null values or not.
# - 2. notnull():
#             - To get the not null values.
# - 3. dropna():
#             - To remove the null values.
# - 4. fillna():
#             - To fill the null values with meaningful data.
# - 5. replace():
#             - To replace the new data.
# - 6. drop():
#             - TO delete the data
# - 7. sort_values:
#             - To sort the data
# - NaN -> not a number

# %%
import pandas as pd
import numpy as np

# %%
# To read the salary_dataset?
df = pd.read_csv('Salary_Data.csv')
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
#1. isnull(): To check the data having null values or not?
# It returns the true or false.
df.isnull()
# Out:
#         Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     False   False            False      False                False   False
# 1     False   False            False      False                False   False
# 2     False   False            False      False                False   False
# 3     False   False            False      False                False   False
# 4     False   False            False      False                False   False
# ...     ...     ...              ...        ...                  ...     ...
# 6699  False   False            False      False                False   False
# 6700  False   False            False      False                False   False
# 6701  False   False            False      False                False   False
# 6702  False   False            False      False                False   False
# 6703  False   False            False      False                False   False
#
# [6704 rows x 6 columns]

# %%
# To count the number of null values from a each column..
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
# To print the only null values records from a dataset.
df[df.isnull().any(axis=1)]
#print(len(df[df.isnull().any(axis=1)]))
# Out:
#        Age  Gender    Education Level            Job Title  \
# 172    NaN     NaN                NaN                  NaN
# 260    NaN     NaN                NaN                  NaN
# 2011  27.0    Male                NaN            Developer
# 3136  31.0    Male    Master's Degree  Full Stack Engineer
# 5247  26.0  Female  Bachelor's Degree             Social M
# 6455  36.0    Male  Bachelor's Degree       Sales Director
#
#       Years of Experience    Salary
# 172                   NaN       NaN
# 260                   NaN       NaN
# 2011                  7.0  100000.0
# 3136                  8.0       NaN
# 5247                  NaN       NaN
# 6455                  6.0       NaN

# %%
# 2. notnull(): it will return the not null records.
# To count the not null values?
df.notnull().sum()
# Out:
# Age                    6702
# Gender                 6702
# Education Level        6701
# Job Title              6702
# Years of Experience    6701
# Salary                 6699
# dtype: int64

# %%
# To print the not null records.
df[df.notnull().any(axis=1)]
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# Notnull method returns the boolean values like true or false.
df.notnull()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0     True    True             True       True                 True    True
# 1     True    True             True       True                 True    True
# 2     True    True             True       True                 True    True
# 3     True    True             True       True                 True    True
# 4     True    True             True       True                 True    True
# ...    ...     ...              ...        ...                  ...     ...
# 6699  True    True             True       True                 True    True
# 6700  True    True             True       True                 True    True
# 6701  True    True             True       True                 True    True
# 6702  True    True             True       True                 True    True
# 6703  True    True             True       True                 True    True
#
# [6704 rows x 6 columns]

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.shape
# Out:
# (6704, 6)

# %%
# 3. dropna(): TO remove the null values...
df.dropna()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# 4. fillna(): To fill the null values with meaningful data.
df.fillna('missing_data',inplace=True)
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df1 = pd.read_csv('Salary_Data.csv')
df1
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0     NaN         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                NaN         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     NaN   65000.0
# 2                    15.0       NaN
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df1.isnull().sum()
# Out:
# Age                    2
# Gender                 3
# Education Level        4
# Job Title              2
# Years of Experience    4
# Salary                 6
# dtype: int64

# %%
df1.fillna('apssdc',inplace=True)
df1
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0  apssdc         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male             apssdc         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                 apssdc   65000.0
# 2                   15.0    apssdc
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ...

# %%
# replace(): TO replace the new data...
s = df1['Salary']
print(s.dtype)
df1['Salary'].replace(to_replace=[90000.0,65000.0],value=[1000,2000],inplace=True)
df1
# Out:
# float64
#        Age  Gender    Education Level              Job Title  \
# 0     32.0     NaN         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                NaN         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0    1000.0
# 1                     NaN    2000.0
# 2                    15.0       NaN
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# To fill the specific column name null values...
df1['Gender'].fillna('hello',inplace=True)
df1
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0   hello         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                NaN         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0    1000.0
# 1                     NaN    2000.0
# 2                    15.0       NaN
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df1.isnull().sum()
# Out:
# Age                    2
# Gender                 0
# Education Level        4
# Job Title              2
# Years of Experience    4
# Salary                 6
# dtype: int64

# %%
# To update the specific column data..
df1.loc[df['Gender']=='Female','Gender'] = 'F'
df1
# To writing the data into a file..
df1.to_csv('Salary_Data.csv',index=False)
df1
# Out:
#        Age Gender    Education Level              Job Title  \
# 0     32.0  hello         Bachelor's      Software Engineer
# 1     28.0      F           Master's           Data Analyst
# 2     45.0   Male                NaN         Senior Manager
# 3     36.0      F         Bachelor's        Sales Associate
# 4     52.0   Male           Master's               Director
# ...    ...    ...                ...                    ...
# 6699  49.0      F                PhD  Director of Marketing
# 6700  32.0   Male        High School        Sales Associate
# 6701  30.0      F  Bachelor's Degree      Financial Manager
# 6702  46.0   Male    Master's Degree      Marketing Manager
# 6703  26.0      F        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0    1000.0
# 1                     NaN    2000.0
# 2                    15.0       NaN
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# drop(): To delete the records..
df1
df1.drop(2,inplace=True,axis=0)
df1
df1.to_csv('Salary_Data.csv',index=False)
df1
# Out:
#        Age Gender    Education Level              Job Title  \
# 3     36.0      F         Bachelor's        Sales Associate
# 4     52.0   Male           Master's               Director
# 5     29.0   Male         Bachelor's      Marketing Analyst
# 6     42.0      F           Master's        Product Manager
# 7     31.0   Male         Bachelor's          Sales Manager
# ...    ...    ...                ...                    ...
# 6699  49.0      F                PhD  Director of Marketing
# 6700  32.0   Male        High School        Sales Associate
# 6701  30.0      F  Bachelor's Degree      Financial Manager
# 6702  46.0   Male    Master's Degree      Marketing Manager
# 6703  26.0      F        High School        Sales Executive
#
#       Years of Experience    Salary
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# 5                     2.0   55000.0
# 6                    12.0  120000.0
# 7                     4.0   80000.0
# ...

# %%
df1.drop('Age',inplace=True,axis=1)
df1
# Out:
#      Gender    Education Level              Job Title  Years of Experience  \
# 3         F         Bachelor's        Sales Associate                  7.0
# 4      Male           Master's               Director                 20.0
# 5      Male         Bachelor's      Marketing Analyst                  2.0
# 6         F           Master's        Product Manager                 12.0
# 7      Male         Bachelor's          Sales Manager                  4.0
# ...     ...                ...                    ...                  ...
# 6699      F                PhD  Director of Marketing                 20.0
# 6700   Male        High School        Sales Associate                  3.0
# 6701      F  Bachelor's Degree      Financial Manager                  4.0
# 6702   Male    Master's Degree      Marketing Manager                 14.0
# 6703      F        High School        Sales Executive                  1.0
#
#         Salary
# 3      60000.0
# 4     200000.0
# 5      55000.0
# ...

# %% [markdown]
# ### groupby():
#         - To group the data using the specific column name..

# %%
gp = df1.groupby('Education Level')
gp

# %%
gp.ngroups
# Out:
# 7

# %%
df1['Education Level'].unique()
#print(len(df1['Education Level'].unique()))
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
# To print total High School records?
gp.get_group('High School')
# Out:
#      Gender Education Level                    Job Title  Years of Experience  \
# 2378  Other     High School      Senior Project Engineer                 31.0
# 2385  Other     High School          Full Stack Engineer                  2.0
# 2395   Male     High School      Senior Project Engineer                 11.0
# 2403   Male     High School           Back end Developer                  7.0
# 2411      F     High School      Senior Project Engineer                  1.0
# ...     ...             ...                          ...                  ...
# 6686   Male     High School  Junior Sales Representative                  3.0
# 6689      F     High School              Sales Associate                  1.0
# 6694   Male     High School    Digital Marketing Manager                  2.0
# 6700   Male     High School              Sales Associate                  3.0
# 6703      F     High School              Sales Executive                  1.0
#
#         Salary
# 2378  166109.0
# ...

# %%
gp1 = df1.groupby('Gender')
gp1.ngroups
# Out:
# 4

# %%
df1['Gender'].unique()
# Out:
# array(['F', 'Male', 'hello', 'Other'], dtype=object)

# %%
gp1.get_group('Other')
# Out:
#      Gender  Education Level                 Job Title  Years of Experience  \
# 2378  Other      High School   Senior Project Engineer                 31.0
# 2385  Other      High School       Full Stack Engineer                  2.0
# 2406  Other  Master's Degree       Full Stack Engineer                 14.0
# 2448  Other      High School        Back end Developer                  8.0
# 2454  Other      High School       Front end Developer                  2.0
# 2458  Other      High School   Senior Project Engineer                 31.0
# 2465  Other      High School       Full Stack Engineer                  2.0
# 2486  Other  Master's Degree       Full Stack Engineer                 14.0
# 2528  Other      High School        Back end Developer                  8.0
# 2534  Other      High School       Front end Developer                  2.0
# 2554  Other      High School  Senior Software Engineer                 29.0
# ...

# %%
# To print the records with gender is others and job title is full stack engineer.
df1[(df1['Gender']=='Other') & (df['Job Title'] == 'Full Stack Engineer')]
# Out:
# <ipython-input-83-64664182a539>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1[(df1['Gender']=='Other') & (df['Job Title'] == 'Full Stack Engineer')]
#      Gender  Education Level            Job Title  Years of Experience  \
# 2385  Other      High School  Full Stack Engineer                  2.0
# 2406  Other  Master's Degree  Full Stack Engineer                 14.0
# 2465  Other      High School  Full Stack Engineer                  2.0
# 2486  Other  Master's Degree  Full Stack Engineer                 14.0
#
#         Salary
# 2385   69032.0
# 2406  161393.0
# 2465   69032.0
# 2486  161393.0
